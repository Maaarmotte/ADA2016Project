# %% [markdown]
# #### Extracting sentiments from news
# This is a description of the news data for future use. Note that it is almost the same steps as for Twitter. For comments, read the twitter\_explore notebook.

# %%
import pandas as pd

# %%
sample = pd.read_json('data/april/harvest3r_news_data_01-04_0.json')

# %%
sample.head()
# Out:
#                    _id                                   _index    _score  \
# 0  1459506675000012800  merged_content_2016_04_01_to_2016_04_14  0.050546
# 1  1459510301000013824  merged_content_2016_04_01_to_2016_04_14  0.031675
# 2  1459506689000004096  merged_content_2016_04_01_to_2016_04_14  0.030112
# 3  1459507789000004352  merged_content_2016_04_01_to_2016_04_14  0.029982
# 4  1459506700000011264  merged_content_2016_04_01_to_2016_04_14  0.029924
#
#                                              _source    _type
# 0  {'index_method': 'PERMALINK_TASK', 'source_res...  content
# 1  {'index_method': 'PERMALINK_TASK', 'source_res...  content
# 2  {'index_method': 'PERMALINK_TASK', 'source_res...  content
# 3  {'index_method': 'PERMALINK_TASK', 'source_res...  content
# 4  {'index_method': 'PERMALINK_TASK', 'source_res...  content

# %%
sample.loc[0]._source
# Out:
# {'bucket': 1459506600061,
#  'canonical': 'http://www.nzz.ch/schweiz/aktuelle-themen/lehrplan-21-thurgauer-will-kein-fruehfranzoesisch-ld.11004',
#  'card': 'SUMMARY',
#  'date_found': '2016-04-01T10:31:15Z',
#  'description': 'Die Regierung in Frauenfeld schickt den neuen Lehrplan für die Primarschule in die Vernehmlassung.',
#  'detection_method': 'FEED',
#  'domain': 'nzz.ch',
#  'duplicates_count': 0,
#  'extract': '<div>\n Lehrplan 21\n</div><div>\n Der Thurgau will kein Fr&uuml;hfranz&ouml;sisch\n</div><div>\n Die Regierung in Frauenfeld schickt den neuen Lehrplan f&uuml;r die Primarschule in die Vernehmlassung. Dieser sieht vor, dass die Kinder ab Mitte 2018 nicht mehr in der Primarschule Franz&ouml;sisch lernen.\n</div>1.4.2016, 12:00 Uhr<h2>Franz&ouml;sischunterricht in der Primarschule? Nicht in Thurgau. (Bild: Jean-Christophe Bott / Keystone)</h2><em>(sda)</em><p> Der Thurgauer Grosse Rat hatte Mitte 2014 beschlossen, den Franz&ouml;sischunterricht auf der Primarstufe zu streichen. Der Thurgau weicht damit vom <a href="http://www.nzz.ch/schweiz/lehrplan-21-freigegeben-1.18420412">interkantonalen Lehrplan 21</a> ab. Entsprechend hat die Regierung den neuen Lehrplan angepasst, wie der Kanton am Freitag mitteilte.</p><p>Weil der bisherige Franz&ouml;sischunterricht in der 5. und 6. Klasse gestrichen wird, m&uuml;ssen auch die Stundentafeln ge&auml;ndert werden: Die w&ouml;chentlichen vier Lektionen aus der Primarschule werden auf die Sekundarstufe verschoben. Das ergibt f&uuml;r die Sekundarsch&uuml;lerinnen und -sch&uuml;ler k&uuml;nftig 14 Lektionen Franz&ouml;sisch.</p><p>Verbindlich festlegen will die Regierung, dass k&uuml;nftig alle Sechstkl&auml;ssler das traditionelle &laquo;Thurgauerlied&raquo; erlernen m&uuml;ssen. Dies wird damit begr&uuml;ndet, dass im Kanton &laquo;die musikalische F&ouml;rderung eine grosse Bedeutung&raquo; geniesse.</p><p>Weiter sieht der neue Thurgauer Lehrplan vor, dass die Sch&uuml;ler ab Mitte 2017 die Deutschschweizer <a href="http://www.nzz.ch/schweiz/basisschrift-statt-schnueerlischrift-1.18417405">&laquo;Basisschrift&raquo;</a> erlernen. Bis Ende Juni k&ouml;nnen Bildungsinstitutionen und -verb&auml;nde, Wirtschaft, Politik, Landeskirchen und weitere Interessierte zum Lehrplan Stellung nehmen.</p><h2>Unterschiedliche Zeitpl&auml;ne</h2><p>Laut Angaben der Deutschschweizer Erziehungsdirektoren haben, ein Jahr nach Vorliegen des Lehrplans 21, bisher 18 der 21 deutsch- und mehrsprachigen Kantone die Einf&uuml;hrung von entsprechenden neuen Lehrpl&auml;nen beschlossen.</p><a href="http://www.nzz.ch/schweiz/stoermanoever-gegen-den-lehrplan-21-1.18440713">Luzern</a><p>, Appenzell-Ausserrhoden, Nidwalden, St. Gallen, Thurgau, Obwalden, <a href="http://www.nzz.ch/schweiz/franzoesisch-nur-als-wahlfach-1.18644813">Glarus</a>, <a href="http://www.nzz.ch/schweiz/stoermanoever-gegen-den-lehrplan-21-1.18440713">Schwyz </a>und <a href="http://www.nzz.ch/schweiz/sonderzueglein-fuer-aargau-uri-und-innerrhoden-1.18415254">Uri </a>wollen ihre neuen Lehrpl&auml;ne im Sommer 2017 einf&uuml;hren. Ein Jahr sp&auml;ter folgen Bern, Graub&uuml;nden, Schaffhausen, Solothurn und <a href="http://www.nzz.ch/zuerich/der-lehrplan-21-kommt-in-zuerich-erst-2017-1.18107757">Z&uuml;rich</a>. Freiburg und <a href="http://www.nzz.ch/schweiz/zug-wehrt-sich-gegen-harmos-durch-die-hintertuer-1.18396005">Zug </a>warten bis 2019.</p><p>Bereits seit Sommer 2015 wird in den Kantonen Basel-Stadt und Basel-Landschaft im Kindergarten und in der Primarschule mit je einem neuen kantonalen Lehrplan auf der Basis des Lehrplans 21 gearbeitet. Noch nicht entschieden ist die Einf&uuml;hrung neuer <a href="http://www.nzz.ch/schweiz/sonderzueglein-fuer-aargau-uri-und-innerrhoden-1.18415254">Lehrpl&auml;ne im Aargau, in Appenzell-Innerrhoden</a> und im Wallis.</p><p>In 13 Kantonen regte sich Widerstand gegen die Einf&uuml;hrung eines einheitlichen Lehrplans. Unter anderem in Z&uuml;rich, Bern, <a href="http://www.nzz.ch/schweiz/demonstration-gegen-abbau-bei-der-bildung-in-aarau-1.18297463">Aargau </a>und Thurgau wurden entsprechende Volksinitiativen eingereicht.</p><h2>Mehr zum Thema</h2><div>\n Der Lehrplan 21 ist schlanker, kommt mit weniger Ideologie aus, benennt Faktenwissen und konkretisiert das ihm zugrunde liegende Bildungsverst&auml;ndnis. Eine Beleuchtung fr&uuml;herer Kritikpunkte.\n</div>von&nbsp;Michael Schoenenberger<div>\n D ...
#  'extract_checksum': '_2jwe-0hL8fNa1amyTC5olAbIRg',
#  'extract_length': 6172,
#  'hashcode': 'lzgsWai0IwvfbjyITxBwkOze0-U',
#  'image_src': 'http://img.nzz.ch/O=75/http://nzz-img.s3.amazonaws.com/2016/4/1/c913cb7b-32d9-4def-a249-ee1ce57bad4c.jpeg',
#  'index_method': 'PERMALINK_TASK',
#  'lang': 'de',
#  'links': ['http://www.nzz.ch/schweiz/basisschrift-statt-schnueerlischrift-1.18417405',
#   'http://www.nzz.ch/schweiz/demonstration-gegen-abbau-bei-der-bildung-in-aarau-1.18297463',
#   'http://www.nzz.ch/schweiz/franzoesisch-nur-als-wahlfach-1.18644813',
#   'http://www.nzz.ch/schweiz/lehrplan-21-freigegeben-1.18420412',
#   'http://www.nzz.ch/schweiz/sonderzueglein-fuer-aargau-uri-und-innerrhoden-1.18415254',
#   'http://www.nzz.ch/schweiz/stoermanoever-gegen-den-lehrplan-21-1.18440713',
#   'http://www.nzz.ch/schweiz/zug-wehrt-sich-gegen-harmos-durch-die-hintertuer-1.18396005',
#   'http://www.nzz.ch/zuerich/der-lehrplan-21-kommt-in-zuerich-erst-2017-1.18107757'],
#  'main': '<p><em>(sda)</em> Der Thurgauer Grosse Rat hatte Mitte 2014 beschlossen, den Franz&ouml;sischunterricht auf der Primarstufe zu streichen. Der Thurgau weicht damit vom <a href="http://www.nzz.ch/schweiz/lehrplan-21-freigegeben-1.18420412">interkantonalen Lehrplan 21</a> ab. Entsprechend hat die Regierung den neuen Lehrplan angepasst, wie der Kanton am Freitag mitteilte.</p>',
#  'main_checksum': 'D-HvMKLyyM-OlgL1pS85Vpy2tfk',
#  'main_format': 'HTML',
#  'main_length': 375,
#  'metadata_score': 322,
#  'permalink': 'http://www.nzz.ch/schweiz/aktuelle-themen/lehrplan-21-thurgauer-will-kein-fruehfranzoesisch-ld.11004',
#  'permalink_redirect': 'http://www.nzz.ch/schweiz/aktuelle-themen/lehrplan-21-thurgauer-will-kein-fruehfranzoesisch-ld.11004',
#  'permalink_redirect_domain': 'nzz.ch',
#  'permalink_redirect_site': 'nzz.ch',
#  'published': '2016-04-01T00:00:00Z',
#  'publisher': 'Neue Zürcher Zeitung',
#  'resource': 'http://nzz.ch/schweiz/aktuelle-themen/lehrplan-21-thurgauer-will-kein-fruehfranzoesisch-ld.11004',
#  'sentiment': 'NEUTRAL',
#  'sequence': 1459506675000012830,
#  'sequence_range': 53061,
#  'site': 'nzz.ch',
#  'source_date_found': '2009-07-08T05:00:00Z',
#  'source_hashcode': 'XgrOtA2i-Wocx5VN-LUeFBijOdQ',
#  'source_link': 'http://nzz.ch/nachrichten/startseite',
#  'source_publisher_type': 'MAINSTREAM_NEWS',
#  'source_resource': 'http://nzz.ch/nachrichten/startseite',
#  'source_setting_update_strategy': 'CYCLICAL',
#  'source_update_interval': 3600000,
#  'tags': ['Schweiz,Aktuelle Themen'],
#  'title': 'Lehrplan 21: Der Thurgau will kein Frühfranzösisch',
#  'type': 'POST',
#  'version': '5.1.683'}

# %%
sample._id.head()
# Out:
# 0    1459506675000012800
# 1    1459510301000013824
# 2    1459506689000004096
# 3    1459507789000004352
# 4    1459506700000011264
# Name: _id, dtype: int64

# %%
sample._id.value_counts().head()
# Out:
# 1459484665000014336    13
# 1459517545000008960    12
# 1459516055000012288    11
# 1459503145000008960    11
# 1459503299000010496    11
# Name: _id, dtype: int64

# %%
len(sample._source)
# Out:
# 2313

# %%
elems = sample._source
ids = sample._id
ids.name = 'id'

# Loop on all elements to get all different fields
columns = set()
for elem in elems:
    if elem.keys() is not None:
        columns.update(elem.keys())
columns = list(columns)

# Pre-allocate the DataFrame, otherwise it takes too much time to fill
# Don't use the elements IDs for filling the DF as they are not unique !
df = pd.DataFrame(columns=columns, index=range(len(ids)))
df.head()
# Out:
#   source_title domain source_last_updated canonical author_name sequence  \
# 0          NaN    NaN                 NaN       NaN         NaN      NaN
# 1          NaN    NaN                 NaN       NaN         NaN      NaN
# 2          NaN    NaN                 NaN       NaN         NaN      NaN
# 3          NaN    NaN                 NaN       NaN         NaN      NaN
# 4          NaN    NaN                 NaN       NaN         NaN      NaN
#
#   source_last_posted source_description publisher resource     ...      \
# 0                NaN                NaN       NaN      NaN     ...
# 1                NaN                NaN       NaN      NaN     ...
# 2                NaN                NaN       NaN      NaN     ...
# 3                NaN                NaN       NaN      NaN     ...
# 4                NaN                NaN       NaN      NaN     ...
#
#   source_resource main_checksum extract_checksum links  \
# 0             NaN           NaN              NaN   NaN
# 1             NaN           NaN              NaN   NaN
# 2             NaN           NaN              NaN   NaN
# 3             NaN           NaN              NaN   NaN
# 4             NaN           NaN              NaN   NaN
#
#   permalink_redirect_site author_gender permalink_redirect_domain  \
# 0                     NaN           NaN                       NaN
# 1                     NaN           NaN                       NaN
# 2                     NaN           NaN                       NaN
# 3                     NaN           NaN                       NaN
# 4                     NaN           NaN                       NaN
#
#   metadata_score version description
# 0            NaN     NaN         NaN
# 1            NaN     NaN         NaN
# 2            NaN     NaN         NaN
# 3            NaN     NaN         NaN
# 4            NaN     NaN         NaN
#
# [5 rows x 66 columns]

# %%
for i in range(len(elems)):
    for key, value in elems[i].items():
        # Convert lists to strings
        if type(value) == list:
            elems[i][key] = ' '.join(value)
        
    df.loc[i] = pd.Series(elems[i])

# Give the elements their original IDs
df.index = ids

df.head()
# Out:
#                     source_title            domain source_last_updated  \
# id
# 1459506675000012800          NaN            nzz.ch                 NaN
# 1459510301000013824          NaN          20min.ch                 NaN
# 1459506689000004096          NaN  tagesanzeiger.ch                 NaN
# 1459507789000004352          NaN        derbund.ch                 NaN
# 1459506700000011264          NaN          20min.ch                 NaN
#
#                                                              canonical  \
# id
# 1459506675000012800  http://www.nzz.ch/schweiz/aktuelle-themen/lehr...
# 1459510301000013824    http://www.20min.ch/schweiz/news/story/31299468
# 1459506689000004096  http://www.tagesanzeiger.ch/schweiz/standard/n...
# 1459507789000004352  http://www.derbund.ch/schweiz/standard/neuer-t...
# 1459506700000011264  http://www.20min.ch/schweiz/ostschweiz/story/1...
#
#                     author_name             sequence source_last_posted  \
# id
# 1459506675000012800         NaN  1459506675000012830                NaN
# 1459510301000013824         NaN  1459510301000013759                NaN
# 1459506689000004096         NaN  1459506689000004006                NaN
# 1459507789000004352         NaN  1459507789000004244                NaN
# 1459506700000011264         NaN  1459506700000011299                NaN
#
#                     source_description             publisher  \
# id
# 1459506675000012800                NaN  Neue Zürcher Zeitung
# 1459510301000013824                NaN            20 Minuten
# 1459506689000004096                NaN     tagesanzeiger.ch/
# 1459507789000004352                NaN           derbund.ch/
# 1459506700000011264                NaN            20 Minuten
#
#                                                               resource  \
# id
# 1459506675000012800  http://nzz.ch/schweiz/aktuelle-themen/lehrplan...
# 1459510301000013824        http://20min.ch/schweiz/news/story/31299468
# 1459506689000004096  http://tagesanzeiger.ch/schweiz/standard/Neuer...
# 1459507789000004352  http://derbund.ch/schweiz/standard/Neuer-Thurg...
# 1459506700000011264  http://20min.ch/schweiz/ostschweiz/story/17349815
#
#                                            ...                          \
# id                                         ...
# 1459506675000012800                        ...
# 1459510301000013824                        ...
# 1459506689000004096                        ...
# 1459507789000004352                        ...
# 1459506700000011264                        ...
#
#                                           source_resource  \
# id
# 1459506675000012800  http://nzz.ch/nachrichten/startseite
# 1459510301000013824                  http://20min.ch/news
# 1459506689000004096          http://tagesanzeiger.ch/auto
# 1459507789000004352                     http://derbund.ch
# 1459506700000011264                  http://20min.ch/news
#
#                                    main_checksum             extract_checksum  \
# id
# 1459506675000012800  D-HvMKLyyM-OlgL1pS85Vpy2tfk  _2jwe-0hL8fNa1amyTC5olAbIRg
# 1459510301000013824                          NaN  4pQdZS9lNRsEWCGm7eYU8IP6mkU
# 1459506689000004096                          NaN  B60CE-ocMNBQvhNV8mAWNnbnMNk
# 1459507789000004352                          NaN  B60CE-ocMNBQvhNV8mAWNnbnMNk
# 1459506700000011264                          NaN  XkqY_oPk9Y4C_q7Jhk0W08ka3Zs
#
#                                                                  links  \
# id
# 1459506675000012800  http://www.nzz.ch/schweiz/basisschrift-statt-s...
# 1459510301000013824  http://www.20min.ch/schweiz/zuerich/story/2082...
# 1459506689000004096                                                NaN
# 1459507789000004352                                                NaN
# 1459506700000011264    http://www.20min.ch/schweiz/news/story/21740109
#
#                     permalink_redirect_site author_gender  \
# id
# 1459506675000012800                  nzz.ch           NaN
# 1459510301000013824                20min.ch           NaN
# 1459506689000004096        tagesanzeiger.ch           NaN
# 1459507789000004352              derbund.ch           NaN
# 1459506700000011264                20min.ch           NaN
#
#                     permalink_redirect_domain metadata_score  version  \
# id
# 1459506675000012800                    nzz.ch            322  5.1.683
# 1459510301000013824                  20min.ch            122  5.1.683
# 1459506689000004096          tagesanzeiger.ch            122  5.1.683
# 1459507789000004352                derbund.ch            122  5.1.683
# 1459506700000011264                  20min.ch            122  5.1.683
#
#                                                            description
# id
# 1459506675000012800  Die Regierung in Frauenfeld schickt den neuen ...
# 1459510301000013824  Eine Störung beim Bahnhof Stein-Säckingen hat ...
# 1459506689000004096  Die Kantonsregierung hat den neuen Lehrplan an...
# 1459507789000004352  Die Kantonsregierung hat den neuen Lehrplan an...
# 1459506700000011264  Die Kantonsregierung hat den neuen Lehrplan an...
#
# [5 rows x 66 columns]

# %%
df['publisher'].value_counts()
# Out:
# Neue Zürcher Zeitung               416
# @Blickch                           407
# az Aargauer Zeitung                258
# tagesanzeiger.ch/                  234
# baz.ch/                            163
# 24heures.ch/                       125
# lematin.ch/                        114
# tdg.ch/                            114
# bz Basellandschaftliche Zeitung    108
# az Limmattaler Zeitung             105
# derbund.ch/                         70
# @letemps                            63
# 20 Minuten                          32
# St.Galler Tagblatt Online            9
# Blog Magazin                         8
# Outdoor                              5
# Sweet Home                           5
# tilllate.com                         4
# Mamablog                             4
# Politblog                            2
# Weinblog                             2
# bernerzeitung.ch/                    1
# «KulturStattBern»                    1
# Stadtblog                            1
# Name: publisher, dtype: int64

# %% [markdown]
# Bad news: it doesn't seem to be geolocalized. It doesn't even have a tag describing where the event they are talking about occurs. We could use the localization of the offices of the journal, but it probably doesn't bring much necessary information.
