# %%
import pandas as pd

# %%
sample = pd.read_json('data/april/harvest3r_instagram_data_01-04_0.json')

# %%
sample.head()
# Out:
#                    _id                                   _index    _score  \
# 0  1459531756000008960  merged_content_2016_04_01_to_2016_04_14  0.095342
# 1  1459531305000012288  merged_content_2016_04_01_to_2016_04_14  0.088152
# 2  1459532576000012288  merged_content_2016_04_01_to_2016_04_14  0.086427
# 3  1459540901000011264  merged_content_2016_04_01_to_2016_04_14  0.078299
# 4  1459528634000012544  merged_content_2016_04_01_to_2016_04_14  0.078229
#
#                                              _source    _type
# 0  {'source_parsed_posts': 0, 'source_setting_aut...  content
# 1  {'source_parsed_posts': 0, 'source_setting_aut...  content
# 2  {'source_parsed_posts': 0, 'source_setting_aut...  content
# 3  {'source_parsed_posts': 0, 'source_setting_aut...  content
# 4  {'source_parsed_posts': 0, 'source_setting_aut...  content

# %%
sample.loc[0]._source
# Out:
# {'author_gender': 'MALE',
#  'author_handle': 'florent_official',
#  'author_link': 'https://www.instagram.com/florent_official/',
#  'author_name': 'Florent R. Photo-Videoprapher',
#  'bucket': 1459531500029,
#  'canonical': 'https://instagram.com/p/BDqoGyZQFKR/',
#  'comments': 0,
#  'date_found': '2016-04-01T17:29:16Z',
#  'detection_method': 'SOURCE',
#  'domain': 'instagram.com',
#  'hashcode': 'szXQ93dSHSSp0fNmvs4v_F0ySsU',
#  'image_height': 360,
#  'image_src': 'https://scontent-frt3-1.cdninstagram.com/t51.2885-15/e15/12317761_1717066748506273_1706016909_n.jpg?ig_cache_key=MTIxODk2MzAzNzQ0NTE4MjA5Nw%3D%3D.2',
#  'image_width': 640,
#  'index_method': 'PERMALINK_TASK',
#  'lang': 'en',
#  'likes': 0,
#  'main': "——————————————————\n•Ort/Location: -\n•Kanton/Canton: -\n•Land/Country: Schweiz/Switzerland\n•Kamera/Camera: Iphone 6 Plus\n•Video by: Me (@florent_official) ————————————————————\n⬛️⬛️⬛️⬛️⬛️⬛️⬛️⬛️⬛️⬛️⬛️⬛️⬛️⬛️\nFlorent R. Photographer on Socialmedia:\n⬇️⬇️⬇️⬇️⬇️⬇️⬇️⬇️⬇️⬇️⬇️⬇️⬇️⬇️\nFacebook Seite: Florent R. Photographer\nFacebook Seite: SBB CFF FFS - Fotoseite\nFacebook Privat: Florent Rx\nInstagram: @sbb_cff_ffs_schweiz\nInstagram: @florent_official\nYoutube Kanal: @sbb_cff_ffs_schweiz's (BIO)\nYoutube Kanal: @florent_official's (BIO)\nWebsite: Coming soon!\n————————————————————\nÄhnliche Tags zur dieses Bild: #Schweiz #Switzerland #Swiss #Bern #Basel #inlovewithswitzerland #Switzerland_Vacations #switzerlandpictures #Super_Switzerland #wu_switzerland #worldunion #visitswitzerland #ig_switzerland #Feuerwehr #Polizei #Ambulance #rbs_ch #sbbcffffs",
#  'main_authoritative': True,
#  'main_checksum': 'WXVLLktjt3QorGGxxD8QO7A6hJ0',
#  'main_format': 'TEXT',
#  'main_length': 839,
#  'metadata_score': 334,
#  'permalink': 'https://instagram.com/p/BDqoGyZQFKR/',
#  'permalink_redirect': 'https://instagram.com/p/BDqoGyZQFKR/',
#  'permalink_redirect_domain': 'instagram.com',
#  'permalink_redirect_site': 'instagram.com',
#  'published': '2016-04-01T17:28:59Z',
#  'resource': 'https://instagram.com/p/BDqoGyZQFKR',
#  'sentiment': 'POSITIVE',
#  'sequence': 1459531756000009008,
#  'sequence_range': 25829,
#  'site': 'instagram.com',
#  'source_content_length': 0,
#  'source_date_found': '2015-12-14T18:55:42Z',
#  'source_description': 'Florent R. Photographer',
#  'source_favicon_height': 0,
#  'source_favicon_width': 0,
#  'source_favorites': 0,
#  'source_followers': -1,
#  'source_following': 0,
#  'source_hashcode': 'SRKQZrUZf2DFrDIYuZ3Ysln0WpM',
#  'source_http_status': 0,
#  'source_image_height': 0,
#  'source_image_width': 0,
#  'source_likes': 0,
#  'source_link': 'https://www.instagram.com/florent_official/',
#  'source_parsed_posts': 0,
#  'source_parsed_posts_max': 0,
#  'source_publisher_subtype': 'instagram',
#  'source_publisher_type': 'PHOTO',
#  'source_resource': 'https://instagram.com/florent_official',
#  'source_setting_author_policy': 'DEFAULT',
#  'source_setting_index_strategy': 'DEFAULT',
#  'source_setting_minimum_content_metadata_score': 0,
#  'source_setting_update_strategy': 'INDIRECT',
#  'source_spam_probability': 0.0,
#  'source_title': 'Florent R. Photographer',
#  'source_update_interval': 0,
#  'source_user_interactions': 0,
#  'source_verified': False,
#  'tags': ['Ambulance',
#   'Basel',
#   'Bern',
#   'Feuerwehr',
#   'Polizei',
#   'Schweiz',
#   'Super_Switzerland',
#   'Swiss',
#   'Switzerland',
#   'Switzerland_Vacations',
#   'ig_switzerland',
#   'inlovewithswitzerland',
#   'rbs_ch',
#   'sbbcffffs',
#   'switzerlandpictures',
#   'visitswitzerland',
#   'worldunion',
#   'wu_switzerland'],
#  'type': 'POST',
#  'version': '5.1.683'}

# %%
sample._id.head()
# Out:
# 0    1459531756000008960
# 1    1459531305000012288
# 2    1459532576000012288
# 3    1459540901000011264
# 4    1459528634000012544
# Name: _id, dtype: int64

# %%
sample._id.value_counts().head()
# Out:
# 1459487029000013568    17
# 1459496502000006912    16
# 1459545427000005632    15
# 1459521935000008960    14
# 1459518346000006912    14
# Name: _id, dtype: int64

# %%
len(sample._source)
# Out:
# 6789

# %%
elems = sample._source
ids = sample._id
ids.name = 'id'

# Loop on all elemements to get all different fields
columns = set()
for elem in elems:
    if elem.keys() is not None:
        columns.update(elem.keys())
columns = list(columns)

# Pre-allocate the DataFrame, otherwise it takes too much time to fill
# Don't use the elements IDs for filling the DF as they are not unique !
df = pd.DataFrame(columns=columns, index=range(len(ids)))
df.head()
# Out:
#   source_parsed_posts source_setting_author_policy author_name  \
# 0                 NaN                          NaN         NaN
# 1                 NaN                          NaN         NaN
# 2                 NaN                          NaN         NaN
# 3                 NaN                          NaN         NaN
# 4                 NaN                          NaN         NaN
#
#   source_setting_index_strategy author_gender source_publisher_type  \
# 0                           NaN           NaN                   NaN
# 1                           NaN           NaN                   NaN
# 2                           NaN           NaN                   NaN
# 3                           NaN           NaN                   NaN
# 4                           NaN           NaN                   NaN
#
#   detection_method source_last_published index_method  \
# 0              NaN                   NaN          NaN
# 1              NaN                   NaN          NaN
# 2              NaN                   NaN          NaN
# 3              NaN                   NaN          NaN
# 4              NaN                   NaN          NaN
#
#   source_publisher_subtype    ...    version bucket comments type  \
# 0                      NaN    ...        NaN    NaN      NaN  NaN
# 1                      NaN    ...        NaN    NaN      NaN  NaN
# 2                      NaN    ...        NaN    NaN      NaN  NaN
# 3                      NaN    ...        NaN    NaN      NaN  NaN
# 4                      NaN    ...        NaN    NaN      NaN  NaN
#
#   source_profiles author_link source_following source_parsed_posts_max  \
# 0             NaN         NaN              NaN                     NaN
# 1             NaN         NaN              NaN                     NaN
# 2             NaN         NaN              NaN                     NaN
# 3             NaN         NaN              NaN                     NaN
# 4             NaN         NaN              NaN                     NaN
#
#   image_src sentiment
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
#
# [5 rows x 73 columns]

# %%
for i in range(len(elems)):
    for key, value in elems[i].items():
        # Convert lists to strings
        if type(value) == list:
            elems[i][key] = ' '.join(value)
        
    df.loc[i] = pd.Series(elems[i])

# Give the elements their original IDs
df.index = ids

df.head()
# Out:
#                     source_parsed_posts source_setting_author_policy  \
# id
# 1459531756000008960                   0                      DEFAULT
# 1459531305000012288                   0                      DEFAULT
# 1459532576000012288                   0                      DEFAULT
# 1459540901000011264                   0                      DEFAULT
# 1459528634000012544                   0                      DEFAULT
#
#                                        author_name  \
# id
# 1459531756000008960  Florent R. Photo-Videoprapher
# 1459531305000012288                        Tatiana
# 1459532576000012288                     Clarissa G
# 1459540901000011264            Nikolaos Orphanidis
# 1459528634000012544                     My Lucerne
#
#                     source_setting_index_strategy author_gender  \
# id
# 1459531756000008960                       DEFAULT          MALE
# 1459531305000012288                       DEFAULT        FEMALE
# 1459532576000012288                       DEFAULT        FEMALE
# 1459540901000011264                       DEFAULT          MALE
# 1459528634000012544                       DEFAULT        FEMALE
#
#                     source_publisher_type detection_method  \
# id
# 1459531756000008960                 PHOTO           SOURCE
# 1459531305000012288                 PHOTO           SOURCE
# 1459532576000012288                 PHOTO           SOURCE
# 1459540901000011264                 PHOTO           SOURCE
# 1459528634000012544                 PHOTO           SOURCE
#
#                     source_last_published    index_method  \
# id
# 1459531756000008960                   NaN  PERMALINK_TASK
# 1459531305000012288                   NaN  PERMALINK_TASK
# 1459532576000012288                   NaN  PERMALINK_TASK
# 1459540901000011264                   NaN  PERMALINK_TASK
# 1459528634000012544                   NaN  PERMALINK_TASK
#
#                     source_publisher_subtype    ...     version  \
# id                                              ...
# 1459531756000008960                instagram    ...     5.1.683
# 1459531305000012288                instagram    ...     5.1.683
# 1459532576000012288                instagram    ...     5.1.683
# 1459540901000011264                instagram    ...     5.1.683
# 1459528634000012544                instagram    ...     5.1.683
#
#                             bucket comments  type source_profiles  \
# id
# 1459531756000008960  1459531500029        0  POST             NaN
# 1459531305000012288  1459531200074        8  POST             NaN
# 1459532576000012288  1459532400071        0  POST             NaN
# 1459540901000011264  1459540800047        0  POST             NaN
# 1459528634000012544  1459528500064        0  POST             NaN
#
#                                                        author_link  \
# id
# 1459531756000008960    https://www.instagram.com/florent_official/
# 1459531305000012288        https://www.instagram.com/tatianatrino/
# 1459532576000012288         https://www.instagram.com/gutschi1974/
# 1459540901000011264  https://www.instagram.com/orphanidisnikolaos/
# 1459528634000012544           https://www.instagram.com/mylucerne/
#
#                     source_following source_parsed_posts_max  \
# id
# 1459531756000008960                0                       0
# 1459531305000012288                0                       0
# 1459532576000012288                0                       0
# 1459540901000011264                0                       0
# 1459528634000012544                0                       0
#
#                                                              image_src  \
# id
# 1459531756000008960  https://scontent-frt3-1.cdninstagram.com/t51.2...
# 1459531305000012288  https://scontent.cdninstagram.com/t51.2885-15/...
# 1459532576000012288  https://scontent-fra3-1.cdninstagram.com/t51.2...
# 1459540901000011264  https://scontent.cdninstagram.com/t51.2885-15/...
# 1459528634000012544  https://scontent-waw1-1.cdninstagram.com/t51.2...
#
#                     sentiment
# id
# 1459531756000008960  POSITIVE
# 1459531305000012288  POSITIVE
# 1459532576000012288   NEUTRAL
# 1459540901000011264       NaN
# 1459528634000012544  POSITIVE
#
# [5 rows x 73 columns]

# %%
df['tags'].head()
# Out:
# id
# 1459531756000008960    Ambulance Basel Bern Feuerwehr Polizei Schweiz...
# 1459531305000012288    PhotoDuJour amazingswitzerland ig_swiss igdail...
# 1459532576000012288    Super_Switzerland Switzerland_Vacations awesom...
# 1459540901000011264    aargau ag art baden badencity badencityaargau ...
# 1459528634000012544    boat ig_swiss ig_switzerland instalucerne inth...
# Name: tags, dtype: object

# %% [markdown]
# Again, we don't have any gelolocalization. But the 'tags' field generally contain the location where the picture has been taken, which is a good start.
