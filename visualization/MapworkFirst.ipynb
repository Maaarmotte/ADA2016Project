# %% [markdown]
# ### In this notebook we deal with cleaning up the twitter data with given sentiments and finding the coordinates for the mentioned locations. In the end we produce some simple folium maps.

# %%
import pandas as pd
import json
import numpy as np
import folium
import nltk
import time
import matplotlib.pyplot as plt
from geopy.geocoders import Nominatim
import math
from geopy.geocoders import Nominatim
import re
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# Creating a dataframe from the combined twitter sentiments data, which has the given sentiment field.

# %%
df = pd.read_csv('processed/sentiments/twitter_sentiments_combined.csv')
df.head()
# Out:
#           City Sentiment  Count  Month Language
# 0       Luzern   NEUTRAL   3069  april       de
# 1  Switzerland  POSITIVE   2246  april       de
# 2        Uster  POSITIVE      8  april       de
# 3   Winterthur  POSITIVE     83  april       de
# 4       Sursee  POSITIVE      3  april       de

# %% [markdown]
# List of words, where Switzerland is in different forms. We will remove records, which city field contains those, as we are interested in the locations such as cities, not countries.

# %%
switzerland = ['schweiz', 'schwyz', 'سويسرا', 'สวิตเซอร์แลนด์', 'スイス','thuy si','ch',
       'suica', 'suisse', 'suiza', 'suíça', 'suïssa', 'svajcarska',
       'sveitsi', 'svizzera', 'swiss', 'switzerland',
       'zwitserland', 'isviçre', 'Швейцария']

# %% [markdown]
# Cleaning up the city field.

# %%
df['City'] = df['City'].map(lambda x: re.sub(r'[^áâçàéèa-zA-ZÖöÜüÄä]+', ' ', x)) #Only latin characters
df['City'] = df['City'].map(lambda x: x.split(' ', 1)[0]) #Selecting the first word
df['City'] = df['City'].map(lambda x: x.lower()) #Converting to lowercase
df = df.loc[~df['City'].isin(switzerland)] #Removing if conatins a word representing Switzerland
df['City'].replace('', np.nan, inplace=True) #Replacing just a whitespace with nan value for later removal
df = df[pd.notnull(df['City'])] #Keeping only records which have a city field

#Keeping only columns of interest, we will aggregate all 10 months data so language and month field get removed.
df = df[['City', 'Sentiment', 'Count']]
df
# Out:
#               City Sentiment  Count
# 0           luzern   NEUTRAL   3069
# 2            uster  POSITIVE      8
# 3       winterthur  POSITIVE     83
# 4           sursee  POSITIVE      3
# 5           saanen   NEUTRAL     74
# 6            baden   NEUTRAL   1398
# 7           meilen   NEUTRAL      8
# 9       waldenburg   NEUTRAL    659
# 10     schleitheim   NEUTRAL      2
# 11        willisau   NEUTRAL     17
# 12      frauenfeld   NEUTRAL    457
# 14          tafers   NEUTRAL      2
# 15            biel  POSITIVE      5
# 16        lausanne   NEUTRAL    395
# 17          sarnen  POSITIVE      1
# 18           buchs   NEUTRAL     17
# 19          zurigo  POSITIVE      3
# 21            thun   NEUTRAL    584
# 22             bad  POSITIVE      2
# 23          bülach  POSITIVE     21
# 24          horgen  POSITIVE      1
# 25           arbon   NEUTRAL      9
# 26           stans   NEUTRAL     63
# 27     kreuzlingen   NEUTRAL     27
# 29           sankt   NEUTRAL    533
# 30            chur   NEUTRAL   1213
# 31         altdorf  POSITIVE      2
# 32            brig  POSITIVE      1
# 33            suhr   NEUTRAL      2
# 34      romanshorn   NEUTRAL     22
# ...            ...       ...    ...
# 89558      chalais   NEUTRAL      2
# 89559       genève   NEUTRAL    154
# 89560           mk   NEUTRAL     59
# 89561      horsham  POSITIVE      1
# 89562            c   NEUTRAL      3
# 89563      yverdon   NEUTRAL      6
# 89565     attalens   NEUTRAL      2
# 89566          val   NEUTRAL      2
# 89567        faoug  POSITIVE     14
# 89568    neverland   NEUTRAL      1
# 89569       annecy  POSITIVE      1
# 89570       morges   NEUTRAL      1
# 89571        salad   NEUTRAL      1
# 89573     orsières   NEUTRAL      3
# 89574       cachée   NEUTRAL      1
# 89575         biel   NEUTRAL      2
# 89576         sion   NEUTRAL    249
# 89577     würenlos   NEUTRAL     10
# 89578       genève   NEUTRAL      3
# 89579       geneva   NEUTRAL      5
# 89580    localhost  POSITIVE      1
# 89582      cottens   NEUTRAL      2
# 89583      verbier   NEUTRAL      1
# 89584      belfaux  POSITIVE      1
# 89585           la   NEUTRAL      4
# 89587        hueco  NEGATIVE      1
# 89588           st   NEUTRAL      1
# 89590    instagram   NEUTRAL      2
# 89591   zollikofen  POSITIVE      1
# 89592     malaysia   NEUTRAL      1
#
# [80356 rows x 3 columns]

# %% [markdown]
# Keeping only the records for which we have positive or negative sentiments by discarding neutral. As there are many neutral sentiments, we believe it gives us a better idea about cities which tend to have positive or negative sentiments.

# %%
df = df.loc[df['Sentiment'].isin(['POSITIVE','NEGATIVE'])]
df.head()
# Out:
#           City Sentiment  Count
# 2        uster  POSITIVE      8
# 3   winterthur  POSITIVE     83
# 4       sursee  POSITIVE      3
# 15        biel  POSITIVE      5
# 17      sarnen  POSITIVE      1

# %%
#df['City'] = pd.core.strings.str_strip(df['City'])
#df.head()

# %% [markdown]
# Grouping by city and sentiment and adding up the counts.

# %%
df = df.groupby(['City','Sentiment'])[('Count')].sum()
df
# Out:
# City              Sentiment
# a                 NEGATIVE         9
#                   POSITIVE        36
# aachen            POSITIVE         3
# aadorf            NEGATIVE         2
#                   POSITIVE        47
# aarau             NEGATIVE       389
#                   POSITIVE      1164
# aarberg           NEGATIVE         1
#                   POSITIVE         4
# aarburg           NEGATIVE        53
#                   POSITIVE        84
# aargau            NEGATIVE       978
#                   POSITIVE      1231
# aarhus            POSITIVE         1
# abadons           NEGATIVE         2
#                   POSITIVE         1
# aberdeen          NEGATIVE         2
#                   POSITIVE         7
# aberdeenshire     POSITIVE         1
# about             POSITIVE         2
# abrantes          POSITIVE         2
# abu               NEGATIVE        81
#                   POSITIVE       119
# abudhabi          NEGATIVE         6
#                   POSITIVE         3
# abuja             NEGATIVE         7
#                   POSITIVE        15
# ac                NEGATIVE         7
#                   POSITIVE         5
# acapulco          POSITIVE         1
#                                ...
# zweisimmen        NEGATIVE        13
#                   POSITIVE        26
# zwickau           POSITIVE         1
# zwolle            NEGATIVE         1
#                   POSITIVE         2
# zöri              POSITIVE         1
# zürcher           NEGATIVE         1
#                   POSITIVE        14
# zürcherstrasse    NEGATIVE         1
#                   POSITIVE        25
# züri              POSITIVE        29
# zürich            NEGATIVE     32842
#                   POSITIVE     89883
# zürichbielbernon  POSITIVE        10
# zürichs           POSITIVE         1
# zürichsee         NEGATIVE         1
#                   POSITIVE        15
# zürih             POSITIVE         2
# zürych            NEGATIVE         1
# à                 NEGATIVE         1
#                   POSITIVE         2
# ägeri             NEGATIVE         1
#                   POSITIVE         1
# österreich        NEGATIVE         1
#                   POSITIVE         8
# ü                 NEGATIVE         1
# überall           NEGATIVE         1
#                   POSITIVE         6
# üt                NEGATIVE        62
#                   POSITIVE       262
# Name: Count, dtype: int64

# %% [markdown]
# Reindexing to get a nice dataframe.

# %%
df = df.reset_index()
df
# Out:
#                   City Sentiment  Count
# 0                    a  NEGATIVE      9
# 1                    a  POSITIVE     36
# 2               aachen  POSITIVE      3
# 3               aadorf  NEGATIVE      2
# 4               aadorf  POSITIVE     47
# 5                aarau  NEGATIVE    389
# 6                aarau  POSITIVE   1164
# 7              aarberg  NEGATIVE      1
# 8              aarberg  POSITIVE      4
# 9              aarburg  NEGATIVE     53
# 10             aarburg  POSITIVE     84
# 11              aargau  NEGATIVE    978
# 12              aargau  POSITIVE   1231
# 13              aarhus  POSITIVE      1
# 14             abadons  NEGATIVE      2
# 15             abadons  POSITIVE      1
# 16            aberdeen  NEGATIVE      2
# 17            aberdeen  POSITIVE      7
# 18       aberdeenshire  POSITIVE      1
# 19               about  POSITIVE      2
# 20            abrantes  POSITIVE      2
# 21                 abu  NEGATIVE     81
# 22                 abu  POSITIVE    119
# 23            abudhabi  NEGATIVE      6
# 24            abudhabi  POSITIVE      3
# 25               abuja  NEGATIVE      7
# 26               abuja  POSITIVE     15
# 27                  ac  NEGATIVE      7
# 28                  ac  POSITIVE      5
# 29            acapulco  POSITIVE      1
# ...                ...       ...    ...
# 6728        zweisimmen  NEGATIVE     13
# 6729        zweisimmen  POSITIVE     26
# 6730           zwickau  POSITIVE      1
# 6731            zwolle  NEGATIVE      1
# 6732            zwolle  POSITIVE      2
# 6733              zöri  POSITIVE      1
# 6734           zürcher  NEGATIVE      1
# 6735           zürcher  POSITIVE     14
# 6736    zürcherstrasse  NEGATIVE      1
# 6737    zürcherstrasse  POSITIVE     25
# 6738              züri  POSITIVE     29
# 6739            zürich  NEGATIVE  32842
# 6740            zürich  POSITIVE  89883
# 6741  zürichbielbernon  POSITIVE     10
# 6742           zürichs  POSITIVE      1
# 6743         zürichsee  NEGATIVE      1
# 6744         zürichsee  POSITIVE     15
# 6745             zürih  POSITIVE      2
# 6746            zürych  NEGATIVE      1
# 6747                 à  NEGATIVE      1
# 6748                 à  POSITIVE      2
# 6749             ägeri  NEGATIVE      1
# 6750             ägeri  POSITIVE      1
# 6751        österreich  NEGATIVE      1
# 6752        österreich  POSITIVE      8
# 6753                 ü  NEGATIVE      1
# 6754           überall  NEGATIVE      1
# 6755           überall  POSITIVE      6
# 6756                üt  NEGATIVE     62
# 6757                üt  POSITIVE    262
#
# [6758 rows x 3 columns]

# %% [markdown]
# Selecting for each city the record, in which the count is the highest, so that the most frequent sentiment is left for each city.

# %%
a = df.loc[df.groupby("City")["Count"].idxmax()]
a.head(20)
a
# Out:
#                   City Sentiment   Count
# 1                    a  POSITIVE      36
# 2               aachen  POSITIVE       3
# 4               aadorf  POSITIVE      47
# 6                aarau  POSITIVE    1164
# 8              aarberg  POSITIVE       4
# 10             aarburg  POSITIVE      84
# 12              aargau  POSITIVE    1231
# 13              aarhus  POSITIVE       1
# 14             abadons  NEGATIVE       2
# 17            aberdeen  POSITIVE       7
# 18       aberdeenshire  POSITIVE       1
# 19               about  POSITIVE       2
# 20            abrantes  POSITIVE       2
# 22                 abu  POSITIVE     119
# 23            abudhabi  NEGATIVE       6
# 26               abuja  POSITIVE      15
# 27                  ac  NEGATIVE       7
# 29            acapulco  POSITIVE       1
# 31               accra  POSITIVE      36
# 33              across  POSITIVE       7
# 34                  ad  POSITIVE       2
# 35              adalar  POSITIVE       1
# 36               addis  POSITIVE       2
# 37             address  NEGATIVE     870
# 40            adelaide  POSITIVE      24
# 42           adelboden  POSITIVE      60
# 43             adelphi  POSITIVE       1
# 45         adligenswil  POSITIVE      10
# 47            adliswil  POSITIVE      33
# 48            adorable  POSITIVE       1
# ...                ...       ...     ...
# 6712          zugerstr  POSITIVE      10
# 6713           zuhause  POSITIVE       1
# 6714          zuidplas  POSITIVE       1
# 6716           zumikon  POSITIVE      19
# 6718           zunzgen  POSITIVE       2
# 6720            zurich  POSITIVE  160666
# 6722            zurigo  POSITIVE     499
# 6723           zurique  NEGATIVE      76
# 6725            zuzwil  POSITIVE      13
# 6726         zvonimira  POSITIVE       1
# 6727       zweibrücken  POSITIVE       6
# 6729        zweisimmen  POSITIVE      26
# 6730           zwickau  POSITIVE       1
# 6732            zwolle  POSITIVE       2
# 6733              zöri  POSITIVE       1
# 6735           zürcher  POSITIVE      14
# 6737    zürcherstrasse  POSITIVE      25
# 6738              züri  POSITIVE      29
# 6740            zürich  POSITIVE   89883
# 6741  zürichbielbernon  POSITIVE      10
# 6742           zürichs  POSITIVE       1
# 6744         zürichsee  POSITIVE      15
# 6745             zürih  POSITIVE       2
# 6746            zürych  NEGATIVE       1
# 6748                 à  POSITIVE       2
# 6749             ägeri  NEGATIVE       1
# 6752        österreich  POSITIVE       8
# 6753                 ü  NEGATIVE       1
# 6755           überall  POSITIVE       6
# 6757                üt  POSITIVE     262
#
# [4458 rows x 3 columns]

# %% [markdown]
# ### The below algorithm runs very long for a large dataframe!
# The solution is in file: coordinatesForGivenSentiments10m.csv
#
# Using the GeoPy package to find the coordinates for all the locations. Those cities or names in the city field which don't have coordinates, will be inserted with nan values.

# %%
geolocator = Nominatim()

def getCoordinates (row):
    #time.sleep(0.01)
    print(row['City'])
    try:
        address, (x, y) = geolocator.geocode(row['City'])
        address = address.split(",")
        country = address[-3]
        return x, y, country
    except Exception:
        return np.nan, np.nan, " "

# %% [markdown]
# Outputing the file with all the coordinates for all the records.

# %%
#a["Latitude"], a["Longitude"], a["Country"]= zip(*a.apply (lambda row: getCoordinates (row),axis=1))
#a

# %%
#outFile = "coordinatesForGivenSentiments10m.csv"
#a.to_csv(outFile,index=None)

# %% [markdown]
# Reading the file with coordinates.

# %%
a = pd.read_csv('coordinatesForGivenSentiments10m.csv')
a.head()
# Out:
#       City Sentiment  Count   Latitude  Longitude Country
# 0      .ch  POSITIVE     14  46.798562   8.231974  Suisse
# 1   aadorf  POSITIVE     47  47.491578   8.902953  Suisse
# 2    aarau  POSITIVE   1164  47.392715   8.044445  Suisse
# 3  aarberg  POSITIVE      4  47.044335   7.275300  Suisse
# 4  aarburg  POSITIVE     84  47.320642   7.899360  Suisse

# %% [markdown]
# ### Find only the data for Switzerland
#
# We only want the records for Switzerland, for which the country field is 'Suisse'.

# %%
a['Country'] = pd.core.strings.str_strip(a['Country'])
a['City'] = pd.core.strings.str_strip(a['City'])
allSuisse = a.loc[a['Country'] == 'Suisse']
allSuisse
# Out:
#               City Sentiment   Count   Latitude  Longitude Country
# 0              .ch  POSITIVE      14  46.798562   8.231974  Suisse
# 1           aadorf  POSITIVE      47  47.491578   8.902953  Suisse
# 2            aarau  POSITIVE    1164  47.392715   8.044445  Suisse
# 3          aarberg  POSITIVE       4  47.044335   7.275300  Suisse
# 4          aarburg  POSITIVE      84  47.320642   7.899360  Suisse
# 5           aargau  POSITIVE    1231  47.412396   8.194832  Suisse
# 6        adelboden  POSITIVE      60  46.492721   7.558762  Suisse
# 7      adligenswil  POSITIVE      10  47.070535   8.368244  Suisse
# 8         adliswil  POSITIVE      33  47.311762   8.524910  Suisse
# 9         aegerten  NEGATIVE       2  47.120241   7.288497  Suisse
# 10          aeschi  NEGATIVE       1  47.180420   7.661874  Suisse
# 11       affoltern  POSITIVE      42  47.418827   8.506867  Suisse
# 12         albinen  POSITIVE      29  46.340644   7.633728  Suisse
# 13     albisrieden  POSITIVE      15  47.374830   8.484558  Suisse
# 14         allaman  POSITIVE      10  46.470778   6.396174  Suisse
# 15        arisdorf  POSITIVE       6  47.512381   7.765508  Suisse
# 16       arlesheim  POSITIVE      18  47.493113   7.620205  Suisse
# 17          arolla  POSITIVE       1  46.025975   7.481087  Suisse
# 18           arosa  POSITIVE      18  46.779725   9.678136  Suisse
# 19            arth  POSITIVE      23  47.064455   8.523867  Suisse
# 20         arveyes  POSITIVE      60  46.291253   7.062685  Suisse
# 21          arzier  POSITIVE      42  46.459981   6.208069  Suisse
# 22          ascona  POSITIVE     247  46.155422   8.770786  Suisse
# 23        attalens  POSITIVE       5  46.511100   6.848970  Suisse
# 24         aubonne  POSITIVE      70  46.495292   6.391575  Suisse
# 25       auenstein  POSITIVE      22  47.416821   8.137060  Suisse
# 26        auslikon  POSITIVE       1  47.344688   8.806375  Suisse
# 27        avenches  POSITIVE       5  46.879575   7.040941  Suisse
# 28           ayent  NEGATIVE       2  46.319024   7.416642  Suisse
# 29            baar  POSITIVE     445  47.194830   8.525613  Suisse
# ..             ...       ...     ...        ...        ...     ...
# 453            who  POSITIVE      10  46.232708   6.134281  Suisse
# 454      wichtrach  POSITIVE       9  46.845731   7.578342  Suisse
# 455         widnau  POSITIVE      15  47.405343   9.635629  Suisse
# 456   wiesendangen  POSITIVE       1  47.521305   8.788990  Suisse
# 457  wiestistrasse  POSITIVE       2  46.022975   7.752309  Suisse
# 458          wikon  POSITIVE       1  47.262811   7.967599  Suisse
# 459     winterthur  POSITIVE    4655  47.499172   8.729150  Suisse
# 460         wohlen  POSITIVE     113  47.350495   8.278691  Suisse
# 461      wohlensee  POSITIVE      13  46.966088   7.316297  Suisse
# 462       wolhusen  POSITIVE       5  47.057470   8.073151  Suisse
# 463       wollerau  POSITIVE     255  47.195724   8.719470  Suisse
# 464      wädenswil  POSITIVE      71  47.227884   8.670198  Suisse
# 465          wängi  POSITIVE      16  47.490930   8.955449  Suisse
# 466        zermatt  POSITIVE    1527  46.022227   7.749400  Suisse
# 467         zernez  POSITIVE      10  46.697984  10.094331  Suisse
# 468        zetzwil  POSITIVE       1  47.286261   8.150826  Suisse
# 469             zg  POSITIVE     139  47.148614   8.553938  Suisse
# 470           zhaw  NEGATIVE       1  47.377624   8.532737  Suisse
# 471       zofingen  POSITIVE   10367  47.288491   7.945826  Suisse
# 472   zollikerberg  POSITIVE       1  47.345664   8.599400  Suisse
# 473     zollikofen  POSITIVE      39  46.995946   7.457642  Suisse
# 474       zollikon  POSITIVE       2  47.339568   8.576126  Suisse
# 475            zrh  POSITIVE     877  47.458280   8.548178  Suisse
# 476        zuchwil  POSITIVE       1  47.203773   7.559418  Suisse
# 477        zuerich  POSITIVE    1059  47.368559   8.540443  Suisse
# 478            zug  POSITIVE    5612  47.167990   8.517365  Suisse
# 479       zugerstr  POSITIVE      10  47.230011   8.614036  Suisse
# 480        zunzgen  POSITIVE       2  47.450401   7.804620  Suisse
# 481         zurich  POSITIVE  160664  47.368559   8.540443  Suisse
# 482         zürich  POSITIVE   89883  47.368559   8.540443  Suisse
#
# [483 rows x 6 columns]

# %%
#outFile = "swissTwitterSentimentsAndCoordinates10m.csv"
#allSuisse.to_csv(outFile,index=None)

# %%
allSuisse = pd.read_csv('swissTwitterSentimentsAndCoordinates10m.csv')
allSuisse.head()
# Out:
#       City Sentiment  Count   Latitude  Longitude Country
# 0      .ch  POSITIVE     14  46.798562   8.231974  Suisse
# 1   aadorf  POSITIVE     47  47.491578   8.902953  Suisse
# 2    aarau  POSITIVE   1164  47.392715   8.044445  Suisse
# 3  aarberg  POSITIVE      4  47.044335   7.275300  Suisse
# 4  aarburg  POSITIVE     84  47.320642   7.899360  Suisse

# %%
allSuisse['City']= allSuisse['City'].map(lambda x: x.title())
allSuisse.head()
# Out:
#       City Sentiment  Count   Latitude  Longitude Country
# 0      .Ch  POSITIVE     14  46.798562   8.231974  Suisse
# 1   Aadorf  POSITIVE     47  47.491578   8.902953  Suisse
# 2    Aarau  POSITIVE   1164  47.392715   8.044445  Suisse
# 3  Aarberg  POSITIVE      4  47.044335   7.275300  Suisse
# 4  Aarburg  POSITIVE     84  47.320642   7.899360  Suisse

# %% [markdown]
# Function which sets the colour column value to reprsent the positive with green colour and negative sentiment with red colour.

# %%
def getColour (row):
   if row['Sentiment'] == 'NEUTRAL' :
      return 'blue'
   if row['Sentiment'] == 'POSITIVE' :
      return 'green'
   if row['Sentiment'] == 'NEGATIVE':
      return 'red'
   return 'black'

# %%
allSuisse['Colour'] = allSuisse.apply (lambda row: getColour (row),axis=1)
allSuisse.head()
# Out:
#       City Sentiment  Count   Latitude  Longitude Country Colour
# 0      .Ch  POSITIVE     14  46.798562   8.231974  Suisse  green
# 1   Aadorf  POSITIVE     47  47.491578   8.902953  Suisse  green
# 2    Aarau  POSITIVE   1164  47.392715   8.044445  Suisse  green
# 3  Aarberg  POSITIVE      4  47.044335   7.275300  Suisse  green
# 4  Aarburg  POSITIVE     84  47.320642   7.899360  Suisse  green

# %% [markdown]
# Simple folium map of Switzerland.

# %%
cantons_geo = r'ch-cantons.topojson.json'
canton_map = folium.Map(location=[46.8, 8.33],tiles='OpenStreetMap', zoom_start=8)
canton_map.choropleth(geo_path = cantons_geo, topojson='objects.cantons', fill_color='#3186cc')
canton_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# Plotting all the cities by using the coordinates and indicating the sentiments with balloon colour.

# %%
for index, row in allSuisse.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row["City"],icon=folium.Icon(color=row["Colour"], icon='ok-sign')).add_to(canton_map)

#canton_map.save( 'mymap.html')

# %%
canton_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#canton_map.save( 'mapForTwitterGivenSentiments10months.html')

# %% [markdown]
# Map with circles around locations, where the radius of the circle correspond with the count of tweets with that sentiment.

# %%
for index, row in allSuisse.iterrows():
    folium.CircleMarker([row['Latitude'], row['Longitude']], radius=row["Count"],popup=row["City"],color=row["Colour"],fill_color=row["Colour"]).add_to(canton_map)

# %%
canton_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
#canton_map.save( 'mapForTwitterGivenSentiments10monthsRadius.html')

# %% [markdown]
# As the circles for some cities like Zürich and Bern are covering the whole map, we decided to try to divide the count by 5 to get a more readable map.

# %%
allSuisse['Count/5'] = allSuisse['Count'].map(lambda x: x/5)
allSuisse.head()
# Out:
#       City Sentiment  Count   Latitude  Longitude Country Colour  Count/5
# 0      .Ch  POSITIVE     14  46.798562   8.231974  Suisse  green      2.8
# 1   Aadorf  POSITIVE     47  47.491578   8.902953  Suisse  green      9.4
# 2    Aarau  POSITIVE   1164  47.392715   8.044445  Suisse  green    232.8
# 3  Aarberg  POSITIVE      4  47.044335   7.275300  Suisse  green      0.8
# 4  Aarburg  POSITIVE     84  47.320642   7.899360  Suisse  green     16.8

# %%
for index, row in allSuisse.iterrows():
    folium.CircleMarker([row['Latitude'], row['Longitude']], radius=row["Count/5"],popup=row["City"],color=row["Colour"],fill_color=row["Colour"]).add_to(canton_map)

# %%
canton_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# On that map we see that Zürich has a large positive circle and also Geneva and a smaller one is around Bern. These are some of the most populated cities in Switzerland, which means more tweets.

# %%
#canton_map.save( 'mapForTwitterGivenSentiments10monthsRadius.html')
